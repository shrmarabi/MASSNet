# %%
#config_file = '../configs/rdsnet/rdsnet_r101_fpn_1x.py'
#checkpoint_file = '../checkpoints/epoch_100.pth'
# download the checkpoint from model zoo and put it in `checkpoints/`
#checkpoint_file = '../checkpoints/resnet101_refine/latest.pth'

# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
# Out:
# /home/rabi_sharma/anaconda3/envs/open-mmlab/lib/python3.7/site-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '
# (1, 256, 56, 56)
# (1, 512, 28, 28)
# (1, 1024, 14, 14)
# (1, 2048, 7, 7)
# Res2Net(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
config_file = '/home/rabi_sharma/Documents/WorkingDirectory/mmdetection/work_dirs/testingfile/res2net_channel/mask_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/home/rabi_sharma/Documents/WorkingDirectory/mmdetection/work_dirs/testingfile/res2net_channel/latest.pth'
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# test a single image
#mmcv.imshow(img)
img=mmcv.imread("10.jpg")
result = inference_detector(model, img)
show_result(img, result, model.CLASSES, show=False, out_file='10_result.jpg')
# Out:
# load checkpoint from local path: /home/rabi_sharma/Documents/WorkingDirectory/mmdetection/work_dirs/testingfile/res2net_channel/latest.pth
# /home/rabi_sharma/anaconda3/envs/open-mmlab/lib/python3.7/site-packages/mmdet-2.27.0-py3.7.egg/mmdet/datasets/utils.py:70: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   'data pipeline in your config file.', UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6357/1672032193.py in <module>
#       7 img=mmcv.imread("10.jpg")
#       8 result = inference_detector(model, img)
# ----> 9 show_result(img, result, model.CLASSES, show=False, out_file='10_result.jpg')
#      10
#
# NameError: name 'show_result' is not defined

# %%
config_file = '../configs/rdsnet/rdsnet_refine_r50_fpn_1x.py'
checkpoint_file = '../checkpoints/resnet50_refine/latest.pth'

# %%
pwd
# Out:
# '/mnt/md0/rabi/mmdetection/demo'

# %%
# test a single image
#mmcv.imshow(img)
img=mmcv.imread("Test_images/Original_10.jpg")
result = inference_detector(model, img)

# %%
show_result(img, result, model.CLASSES, show=False, out_file='rdsnet10.jpg')

# %%
show_result(img, result, model.CLASSES, show=False, out_file='rdsnet34.jpg')

# %%
print(type(model.CLASSES))
a=model.CLASSES
my_result=tuple(map(str,a))
print(my_result)
# Out:
# <class 'str'>
# ('b', 'o', 'a', 't')

# %%
# show the results
#print(type(model.CLASSES))
#!pwd
show_result_pyplot(img, result, model.CLASSES)
#show_result_pyplot(model, result, img, score_thr=score_thr)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1984/3851887342.py in <module>
#       2 #print(type(model.CLASSES))
#       3 #!pwd
# ----> 4 show_result_pyplot(img, result, model.CLASSES)
#       5 #show_result_pyplot(model, result, img, score_thr=score_thr)
#
# /mnt/md0/rabi/RDSNet/mmdet/apis/inference.py in show_result_pyplot(img, result, class_names, score_thr, fig_size)
#     167             be written to the out file instead of shown in a window.
#     168     """
# --> 169     img = show_result(
#     170         img, result, class_names, score_thr=score_thr, show=False)
#     171     plt.figure(figsize=fig_size)
#
# /mnt/md0/rabi/RDSNet/mmdet/apis/inference.py in show_result(img, result, class_names, score_thr, wait_time, show, out_file)
#     114             visualized image is returned, otherwise None is returned.
#     115     """
# ...
