# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
# Out:
# /home/rabi_sharma/anaconda3/envs/openlab/lib/python3.7/site-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '
# (1, 256, 56, 56)
# (1, 512, 28, 28)
# (1, 1024, 14, 14)
# (1, 2048, 7, 7)

# %%
config_file = '../work_dirs/testfiles/solo_r50_fpn_1x_coco.py'

checkpoint_file = '../work_dirs/testfiles/latest.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ../work_dirs/testfiles/latest.pth

# %%
# test a single image
img = '5.jpg'
result = inference_detector(model, img)# show the results
show_result_pyplot(model, img, result)

# %%
# show the results
show_result_pyplot(model, img, result)

# %%
# !ls
# Out:
# 10.jpg		       inference_demo.ipynb		 Testing
# 1.jpg		       latest.pth			 train_loss.svg
# 4.jpg		       mask_rcnn_r50_fpn_1x_coco.py	 Untitled.ipynb
# create_result_gif.py   MMDet_InstanceSeg_Tutorial.ipynb  video_demo.py
# demo.jpg	       MMDet_Tutorial.ipynb		 video_gpuaccel_demo.py
# demo.mp4	       run-.-tag-learning_rate.csv	 webcam_demo.py
# image_demo.py	       test_images
# inference_demo1.ipynb  testImages

# %%
import os
print(os.getcwd())
# Out:
# /mnt/md0/rabi/mmdetection/demo

# %%
import os
print(os.path.exists('/home/rabi_sharma/Documents/WorkingDirectory/mmdetection/demo/epoch_10.pth'))  # replace with your actual path
# Out:
# True
